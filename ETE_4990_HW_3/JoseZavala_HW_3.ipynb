# %% [markdown]
# JOSE ZAVALA

# %%
import json
import os

# Full path to your JSON file
file_path = r"students.json"

def print_all_student_info(json_file):
    if not os.path.exists(json_file):
        print(f"[Error] File not found: {json_file}")
        return

    try:
        with open(json_file, "r") as file:
            students = json.load(file)

        print("[Student Records in students.json]:\n")
        for i, student in enumerate(students, 1):
            print(f"Student {i}")
            print("------------")
            for key, value in student.items():
                print(f"{key.replace('_', ' ').title()}: {value}")
            print()
    except json.JSONDecodeError:
        print("[Error] Failed to decode JSON file.")

# Run it
print_all_student_info(file_path)
# Out:
# [Student Records in students.json]:
#
# Student 1
# ------------
# First Name: John
# Last Name: Tylor
# Street Address: 123 Maple St
# Email: john.tylor@example.com
# Age: 25
# Birthdate: 1999-01-15
# Index Number: 1
#
# Student 2
# ------------
# First Name: Jane
# Last Name: Tylor
# Street Address: 456 Oak St
# Email: jane.tylor@example.com
# Age: 30
# Birthdate: 1994-02-20
# Index Number: 2
#
# Student 3
# ------------
# First Name: Michael
# Last Name: Tylor
# Street Address: 789 Pine St
# Email: michael.tylor@example.com
# Age: 35
# Birthdate: 1989-03-25
# Index Number: 3
#
# Student 4
# ------------
# First Name: Emily
# Last Name: Tylor
# Street Address: 101 Birch St
# Email: emily.tylor@example.com
# Age: 28
# Birthdate: 1996-04-30
# Index Number: 4
#
# Student 5
# ------------
# First Name: David
# Last Name: Tylor
# Street Address: 202 Cedar St
# Email: david.tylor@example.com
# Age: 40
# Birthdate: 1984-05-05
# Index Number: 5

# %% [markdown]
# Used ChatGPT to help with code
