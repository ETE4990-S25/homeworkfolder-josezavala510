# %%
include <stdio.h>
include <math.h>

int main()
{
    unsigned char LUT[256];
    unsigned int i;
    unsigned char result;

    printf("const unsigned char LUT[256] = {\n");
    for(i=0; i<256; i++)
    {
        // modify the "result = ...." line for your sine wave!
        result = (unsigned char) exp(i*log(255)/256);    
        printf("%d", result);
        if(i != 255)
            printf(",");
        if(i%51 == 50)
            printf("\n");
    }
    printf("};");

    return 0;
}
# Out:
#   Cell In[8], line 1
#     include <stdio.h>
#                      ^
# SyntaxError: invalid syntax
